# %%
{{"glycine", "2-aminoacetic acid", \!\(\*
StyleBox[
TemplateBox[{
    "\"N\"",SubscriptBox["\"H\"", "2"],"\"C\"",SubscriptBox[
     "\"H\"", "2"],"\"C\"","\"O\"","\"O\"","\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[75.07, ("Grams")/("Moles")], 
  "C(C(=O)O)N", {"GGU", "GGC", "GGA", "GGG"}, {0.00446684, 
   1.65959*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{-71.45, 1.03}, {0., 
    42.28}, {-71.45, -81.47}, {71.45, 1.03}, {0., 
    124.78}, {0., -122.72}, {-131.26, -124.78}, {142.89, 
    42.28}, {0., -40.22}, {-142.89, 42.28}}, {"C", "C", "N", "O", "O",
    "H", "H", "H", "H", "H"}}, {"L-alanine", 
  "(2S)-2-aminopropanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "3"],SubscriptBox["\"H\"", "7"],"\"N\"",
     SubscriptBox["\"O\"", "2"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[89.09, ("Grams")/("Moles")], 
  "CC(C(=O)O)N", {"GCU", "GCC", "GCA", "GCG"}, {0.00446684, 
   1.34896*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{513.5, -25.}, {426.9, 
    125.}, {253.69, 25.}, {340.3, -25.}, {340.3, -125.}, {426.9, 
    25.}, {340.3, 
    37.}, {278.3, -125.}, {340.3, -187.}, {402.3, -125.}, {200., \
-6.}, {253.69, 87.}, {567.2, 6.}}, {"O", "O", "N", "C", "C", "C", "H",
    "H", "H", "H", "H", "H", "H"}}, {"L-serine", 
  "2-amino-3-hydroxy-propanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "3"],SubscriptBox["\"H\"", "7"],"\"N\"",
     SubscriptBox["\"O\"", "3"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[105.09, ("Grams")/("Moles")], 
  "C(C(C(=O)O)N)O", {"UCU", "UCC", "UCA", "UCG", "AGU", 
   "AGC"}, {0.00645654, 
   6.16595*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/(
    "Moles")]}, {{253.69, -119.}, {513.5, 31.}, {426.9, 
    181.}, {253.69, 81.}, {340.3, 31.}, {340.3, -69.}, {426.9, 
    81.}, {340.3, 93.}, {361.5, -127.26}, {401.35, -58.23}, {200., 
    50.}, {253.69, 143.}, {253.69, -181.}, {567.19, 62.}}, {"O", "O", 
   "O", "N", "C", "C", "C", "H", "H", "H", "H", "H", "H", 
   "H"}}, {"L-proline", "(2S)-2-pyrrolidinecarboxylic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "5"],SubscriptBox["\"H\"", "9"],"\"N\"",
     SubscriptBox["\"O\"", "2"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[115.13, ("Grams")/("Moles")], 
  "C1CC(NC1)C(=O)O", {"CCU", "CCC", "CCA", "CCG"}, {0.0112202, 
   2.29087*10^-11}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{531.22, 
    52.82}, {477.7, -111.91}, {280.9, -41.97}, {361.8, 16.81}, {330.9,
     111.91}, {230.9, 111.91}, {200., 
    16.81}, {456.91, -14.1}, {371.5, -44.43}, {391.55, 
    124.8}, {324.42, 173.57}, {237.38, 173.57}, {170.26, 
    124.8}, {143.36, 
    42.02}, {169., -36.89}, {280.9, -103.97}, {590.19, 33.66}}, {"O", 
   "O", "N", "C", "C", "C", "C", "C", "H", "H", "H", "H", "H", "H", 
   "H", "H", "H"}}, {"L-valine", 
  "(2S)-2-azaniumyl-3-methyl-butanoate", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "5"],SubscriptBox["\"H\"", "11"],"\"N\"",
     SubscriptBox["\"O\"", "2"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[117.15, ("Grams")/("Moles")], 
  "CC(C)C(C(=O)[O-])[NH3+]", {"GUU", "GUC", "GUA", "GUG"}, {0.0040738,
    1.8197*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/(
    "Moles")]}, {{546.41, -9.5}, {459.81, 
    140.5}, {373.21, -109.5}, {286.6, 
    40.5}, {373.21, -9.5}, {200., -9.5}, {286.6, 140.5}, {459.81, 
    40.5}, {286.6, -21.5}, {426.9, -40.5}, {231., -63.19}, {146.31, \
-40.5}, {169., 44.19}, {224.6, 140.5}, {286.6, 202.5}, {348.6, 
    140.5}, {319.51, -140.5}, {426.9, -140.5}, {600.1, 21.5}}, {"O", 
   "O", "N", "C", "C", "C", "C", "C", "H", "H", "H", "H", "H", "H", 
   "H", "H", "H", "H", "H"}}, {"L-threonine", 
  "(2S,3R)-2-azaniumyl-3-hydroxy-butanoate", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "4"],SubscriptBox["\"H\"", "9"],"\"N\"",
     SubscriptBox["\"O\"", "3"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[119.12, ("Grams")/("Moles")], 
  "CC(C(C(=O)[O-])[NH3+])O", {"ACU", "ACC", "ACA", 
   "ACG"}, {0.00812831, 
   7.94328*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/(
    "Moles")]}, {{-8.79, -36.85}, {62.65, 
    4.4}, {-8.79, -119.35}, {134.1, -36.85}, {62.65, 
    86.9}, {62.65, -160.6}, {-68.61, -162.66}, {205.55, 
    4.4}, {62.65, -78.1}, {-66.54, -5.91}, {-135.24, -53.14}, {-77.45,
     80.44}, {-205.55, -6.86}, {-152.05, 115.67}, {-9.64, 
    127.43}, {-84.24, 162.66}, {-1.34, 42.94}}, {"C", "C", "N", "O", 
   "O", "H", "H", "H", "H", "C", "O", "C", "H", "H", "H", "H", 
   "H"}}, {"L-cysteine", 
  "(2R)-2-amino-3-mercaptopropanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    "\"H\"","\"S\"","\"C\"",SubscriptBox["\"H\"", "2"],"\"C\"",
     "\"H\"",TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[121.15, ("Grams")/("Moles")], 
  "C(C(C(=O)O)N)S", {"UGU", "UGC"}, {0.0120226, 6.60693*10^-9, 
   1.99526*10^-11}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[272., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")], 
   Quantity[363., ("Kilojoules")/(
    "Moles")]}, {{253.69, -119.}, {513.5, 31.}, {426.9, 
    181.}, {253.69, 81.}, {340.3, 31.}, {340.3, -69.}, {426.9, 
    81.}, {340.3, 93.}, {361.5, -127.26}, {401.35, -58.23}, {200., 
    50.}, {253.69, 143.}, {253.69, -181.}, {567.19, 62.}}, {"S", "O", 
   "O", "N", "C", "C", "C", "H", "H", "H", "H", "H", "H", 
   "H"}}, {"L-isoleucine", "2-amino-3-methyl-pentanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "6"],SubscriptBox["\"H\"", "13"],"\"N\"",
     SubscriptBox["\"O\"", "2"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[131.18, ("Grams")/("Moles")], 
  "CCC(C)C(C(=O)O)N", {"AUU", "AUC", "AUA"}, {0.0047863, 
   1.7378*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{253.69, -9.5}, {340.3,
     140.5}, {426.9, -109.5}, {513.5, 
    40.5}, {426.9, -9.5}, {600.1, -9.5}, {513.5, 140.5}, {686.71, 
    40.5}, {340.3, 40.5}, {567.19, 
    71.5}, {480.59, -40.5}, {560.25, -56.99}, {639.96, -56.99}, \
{575.5, 140.5}, {513.5, 202.5}, {451.5, 
    140.5}, {717.71, -13.19}, {740.4, 71.5}, {655.71, 
    94.19}, {480.59, -140.5}, {373.21, -140.5}, {200., 21.5}}, {"O", 
   "O", "N", "C", "C", "C", "C", "C", "C", "H", "H", "H", "H", "H", 
   "H", "H", "H", "H", "H", "H", "H", "H"}}, {"L-leucine", 
  "(2S)-2-amino-4-methylpentanoic acid", \!\(\*
StyleBox[
TemplateBox[{SubscriptBox[
TemplateBox[{"\"(\"", "\"C\"", 
SubscriptBox["\"H\"", "3"], "\")\""}, "RowDefault"], "2"],"\"C\"",
     "\"H\"","\"C\"",SubscriptBox["\"H\"", "2"],"\"C\"","\"H\"",
     TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[131.18, ("Grams")/("Moles")], 
  "CC(C)CC(C(=O)O)N", {"UUA", "UUG", "CUU", "CUC", "CUA", 
   "CUG"}, {0.00467735, 
   1.8197*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{-107.17, 
    20.62}, {-35.72, 61.87}, {35.72, 20.62}, {107.17, 
    61.87}, {35.72, -61.88}, {178.62, 20.62}, {107.17, 
    144.37}, {107.17, -103.13}, {-24.09, -105.2}, {-35.72, 
    144.37}, {35.72, 103.12}, {250.06, 
    61.87}, {107.17, -20.63}, {-178.62, 
    61.87}, {-107.17, -61.88}, {-107.17, 103.12}, {-250.06, 
    20.62}, {-178.62, 144.37}, {-250.06, 
    103.12}, {-178.62, -103.13}, {-178.62, -20.63}, {-105.4, \
-144.37}}, {"C", "C", "C", "C", "N", "O", "O", "H", "H", "H", "H", 
   "H", "H", "C", "C", "H", "H", "H", "H", "H", "H", 
   "H"}}, {"L-asparagine", "2-amino-3-carbamoyl-propanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "4"],SubscriptBox["\"H\"", "8"],
     SubscriptBox["\"N\"", "2"],SubscriptBox["\"O\"", "3"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[132.12, ("Grams")/("Moles")], 
  "C(C(C(=O)O)N)C(=O)N", {"AAU", "AAC"}, {0.00724436, 
   1.90546*10^-9}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{686.71, -9.5}, {600.1,
     140.5}, {340.3, -109.5}, {513.5, -109.5}, {253.69, 
    40.5}, {513.5, -9.5}, {426.9, 40.5}, {600.1, 
    40.5}, {340.3, -9.5}, {567.19, -40.5}, {466.75, 87.99}, {387.05, 
    87.99}, {459.81, -140.5}, {567.19, -140.5}, {200., 9.5}, {253.69, 
    102.5}, {740.4, 21.5}}, {"O", "O", "O", "N", "N", "C", "C", "C", 
   "C", "H", "H", "H", "H", "H", "H", "H", "H"}}, {"L-aspartic acid", 
  "(2S)-2-aminobutanedioic acid", \!\(\*
StyleBox[
TemplateBox[{
    "\"H\"",SubscriptBox["\"O\"", "2"],"\"C\"","\"C\"",SubscriptBox[
     "\"H\"", "2"],"\"C\"","\"H\"",TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[133.10, ("Grams")/("Moles")], 
  "C(C(C(=O)O)N)C(=O)O", {"GAU", "GAC"}, {0.0102329, 0.000125893, 
   1.25893*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/(
    "Moles")]}, {{686.71, -9.5}, {253.69, 40.5}, {600.1, 
    140.5}, {340.3, -109.5}, {513.5, -109.5}, {513.5, -9.5}, {426.9, 
    40.5}, {600.1, 40.5}, {340.3, -9.5}, {587.11, -52.}, {466.75, 
    87.99}, {387.05, 
    87.99}, {459.81, -140.5}, {567.2, -140.5}, {740.4, 21.5}, {200., 
    9.5}}, {"O", "O", "O", "O", "N", "C", "C", "C", "C", "H", "H", 
   "H", "H", "H", "H", "H"}}, {"L-glutamine", 
  "(2S)-2-azaniumyl-4-carbamoyl-butanoate", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "5"],SubscriptBox["\"H\"", "10"],
     SubscriptBox["\"N\"", "2"],SubscriptBox["\"O\"", "3"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[146.15, ("Grams")/("Moles")], 
  "C(CC(=O)N)C(C(=O)[O-])[NH3+]", {"CAA", "CAG"}, {0.00676083, 
   7.4131*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")]}, {{253.69, 106.}, {340.3,
     256.}, {426.9, -194.}, {513.5, 156.}, {253.69, -194.}, {426.9, 
    106.}, {426.9, 6.}, {340.3, -44.}, {340.3, 
    156.}, {340.3, -144.}, {426.9, 168.}, {448.1, -52.26}, {487.96, 
    16.77}, {319.09, 14.26}, {279.24, -54.77}, {567.2, 187.}, {544.5, 
    102.31}, {482.5, 209.69}, {253.69, -256.}, {200., -163.}}, {"O", 
   "O", "O", "N", "N", "C", "C", "C", "C", "C", "H", "H", "H", "H", 
   "H", "H", "H", "H", "H", "H"}}, {"L-lysine", 
  "(2S)-2,6-diaminohexanoic acid", \!\(\*
StyleBox[
TemplateBox[{SubscriptBox["\"H\"", "2"],"\"N\"",SubscriptBox[
TemplateBox[{"\"(\"", "\"C\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"], "4"],"\"C\"",
     "\"H\"",TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[146.19, ("Grams")/("Moles")], 
  "C(CCN)CC(C(=O)O)N", {"AAA", "AAG"}, {0.00691831, 2.88403*10^-11, 
   8.70964*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{140.5, 600.1}, {290.5,
     513.5}, {190.5, 340.3}, {-259.5, 253.69}, {-9.5, 340.3}, {40.5, 
    426.9}, {-109.5, 340.3}, {140.5, 426.9}, {-159.5, 253.69}, {190.5,
     513.5}, {48.76, 319.09}, {-20.27, 279.24}, {-17.76, 
    448.1}, {51.27, 487.96}, {-167.76, 361.5}, {-98.73, 
    401.35}, {202.5, 426.9}, {-101.24, 232.49}, {-170.27, 
    192.64}, {252.5, 340.3}, {159.5, 286.6}, {-290.5, 200.}, {-290.5, 
    307.39}, {171.5, 653.8}}, {"O", "O", "N", "N", "C", "C", "C", "C",
    "C", "C", "H", "H", "H", "H", "H", "H", "H", "H", "H", "H", "H", 
   "H", "H", "H"}}, {"L-glutamic acid", 
  "(2S)-2-aminopentanedioic acid", \!\(\*
StyleBox[
TemplateBox[{
    "\"H\"",SubscriptBox["\"O\"", "2"],"\"C\"","\"C\"",SubscriptBox[
     "\"H\"", "2"],"\"C\"",SubscriptBox["\"H\"", "2"],"\"C\"","\"H\"",
     TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[147.13, ("Grams")/("Moles")], 
  "C(CC(=O)O)C(C(=O)O)N", {"GAA", "GAG"}, {0.00794328, 0.0000851138, 
   3.38844*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{106., 546.41}, {-194.,
     200.}, {256., 459.81}, {-194., 373.21}, {156., 286.6}, {6., 
    373.21}, {106., 373.21}, {-44., 286.6}, {156., 459.81}, {-144., 
    286.6}, {-52.26, 394.41}, {16.77, 434.26}, {168., 373.21}, {14.26,
     265.4}, {-54.77, 225.54}, {125., 232.91}, {218., 286.6}, {137., 
    600.1}, {-256., 200.}}, {"O", "O", "O", "O", "N", "C", "C", "C", 
   "C", "C", "H", "H", "H", "H", "H", "H", "H", "H", 
   "H"}}, {"L-methionine", 
  "2-amino-4-methylsulfanyl-butanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "5"],SubscriptBox["\"H\"", "11"],"\"N\"",
     SubscriptBox["\"O\"", "2"],"\"S\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[149.21, ("Grams")/("Moles")], 
  "CSCCC(C(=O)O)N", {"AUG"}, {0.0074131, 
   5.24807*10^-10}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[272., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{-175., 286.6}, {75., 
    546.41}, {225., 459.81}, {125., 286.6}, {-25., 373.21}, {75., 
    373.21}, {-75., 286.6}, {125., 459.81}, {-225., 200.}, {-14.23, 
    434.26}, {-83.26, 394.41}, {137., 373.21}, {-16.74, 
    265.4}, {-85.77, 225.54}, {187., 286.6}, {94., 232.91}, {-171.31, 
    169.}, {-256., 146.31}, {-278.69, 231.}, {106., 600.1}}, {"S", 
   "O", "O", "N", "C", "C", "C", "C", "C", "H", "H", "H", "H", "H", 
   "H", "H", "H", "H", "H", "H"}}, {"L-histidine", 
  "(2S)-2-amino-3-(1H-imidazol-5-yl)propanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "6"],SubscriptBox["\"H\"", "9"],
     SubscriptBox["\"N\"", "3"],SubscriptBox["\"O\"", "2"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[155.16, ("Grams")/("Moles")], 
  "C1=C(NC=N1)CC(C(=O)O)N", {"CAU", "CAC"}, {0.0158489, 9.12011*10^-7,
    4.67735*10^-10}, {Quantity[602., ("Kilojoules")/("Moles")], 
   Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[615., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{700.64, 
    44.76}, {647.12, -119.97}, {280.9, -86.05}, {510.43, 
    106.56}, {230.9, 67.84}, {456.91, -58.17}, {531.22, 
    8.74}, {361.8, -27.27}, {626.33, -22.16}, {330.9, 
    67.84}, {200., -27.27}, {427.8, -112.91}, {505.77, -96.34}, \
{472.26, 27.9}, {280.9, -148.04}, {367.34, 118.}, {556.51, 
    148.04}, {451.47, 125.72}, {141.03, -46.43}, {759.61, 
    25.6}}, {"O", "O", "N", "N", "N", "C", "C", "C", "C", "C", "C", 
   "H", "H", "H", "H", "H", "H", "H", "H", "H"}}, {"L-phenylalanine", 
  "(2S)-2-amino-3-phenylpropanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "6"],SubscriptBox["\"H\"", "5"],"\"C\"",
     SubscriptBox["\"H\"", "2"],"\"C\"","\"H\"",
     TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[165.19, ("Grams")/("Moles")], 
  "C1=CC=C(C=C1)CC(C(=O)O)N", {"UUU", "UUC"}, {0.00630957, 
   4.89779*10^-10}, {Quantity[602., ("Kilojoules")/("Moles")], 
   Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{219., 459.81}, {219., 
    286.6}, {19., 459.81}, {19., 286.6}, {69., 373.21}, {-81., 
    286.6}, {-131., 373.21}, {-131., 200.}, {169., 373.21}, {-231., 
    373.21}, {-231., 200.}, {-281., 286.6}, {77.26, 265.4}, {8.23, 
    225.54}, {7., 373.21}, {-100., 426.9}, {-100., 146.31}, {50., 
    513.5}, {-43., 459.81}, {-262., 426.9}, {-262., 146.31}, {-343., 
    286.6}, {281., 459.81}}, {"O", "O", "N", "C", "C", "C", "C", "C", 
   "C", "C", "C", "C", "H", "H", "H", "H", "H", "H", "H", "H", "H", 
   "H", "H"}}, {"L-arginine", 
  "(2S)-2-amino-5-(diaminomethylideneamino)pentanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"H\"", "2"],"\"N\"","\"C\"",
     TemplateBox[{"\"(\"", "\"=\"", "\"N\"", "\"H\"", "\")\""}, 
      "RowDefault"],"\"N\"","\"H\"",SubscriptBox[
TemplateBox[{"\"(\"", "\"C\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"], "3"],"\"C\"",
     "\"H\"",TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[174.20, ("Grams")/("Moles")], 
  "NC(CCCN=C(N)N)C(O)=O", {"CGU", "CGC", "CGA", "CGG", "AGA", 
   "AGG"}, {0.0151356, 3.31131*10^-13, 
   1.02329*10^-9}, {Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[615., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/(
    "Moles")]}, {{-142.89, -20.62}, {-71.45, 
    20.62}, {0., -20.62}, {71.45, 20.62}, {142.89, -20.62}, {214.34, 
    20.62}, {285.79, -20.62}, {214.34, 103.13}, {-214.34, 
    20.62}, {-142.89, -103.13}, {-285.79, -20.62}, {-214.34, 
    103.13}, {-357.24, 
    20.62}, {142.89, -103.13}, {-71.45, -144.38}, {-214.34, -144.38}, \
{357.24, 20.62}, {285.79, -103.13}, {142.89, 144.38}, {-71.45, 
    103.13}, {0., 61.88}, {71.45, 103.13}, {142.89, 
    61.88}, {0., -103.13}, {71.45, -61.88}, {-142.89, 61.88}}, {"C", 
   "C", "C", "C", "N", "C", "N", "N", "C", "N", "O", "O", "H", "H", 
   "H", "H", "H", "H", "H", "H", "H", "H", "H", "H", "H", 
   "H"}}, {"L-tyrosine", 
  "(2S)-2-amino-3-(4-hydroxyphenyl)propanoic acid", \!\(\*
StyleBox[
TemplateBox[{
    TemplateBox[{"\"(\"", "\"H\"", "\"O\"", "\")\""}, "RowDefault"],
     SubscriptBox["\"C\"", "6"],SubscriptBox["\"H\"", "4"],"\"C\"",
     SubscriptBox["\"H\"", "2"],"\"C\"","\"H\"",
     TemplateBox[{"\"(\"", "\"N\"", 
SubscriptBox["\"H\"", "2"], "\")\""}, "RowDefault"],"\"C\"",
     SubscriptBox["\"O\"", "2"],"\"H\""},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[181.19, ("Grams")/("Moles")], 
  "C1=CC(=CC=C1CC(C(=O)O)N)O", {"UAU", "UAC"}, {0.00630957, 
   3.46737*10^-11, 
   6.16595*10^-10}, {Quantity[602., ("Kilojoules")/("Moles")], 
   Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/("Moles")]}, {{-178.62, 
    41.25}, {-178.62, -41.25}, {-107.17, -82.5}, {-35.72, -41.25}, \
{-35.72, 41.25}, {-107.17, 82.5}, {-250.06, -82.5}, {35.72, 
    82.5}, {107.17, 41.25}, {178.62, 82.5}, {107.17, -41.25}, {250.06,
     41.25}, {178.62, 165.}, {-321.51, -41.25}, {-250.06, 
    82.5}, {-107.17, 
    165.}, {-3.46, -103.13}, {-107.17, -165.}, {178.62, -82.5}, \
{47.36, -84.56}, {35.72, 165.}, {107.17, 123.75}, {321.51, 
    82.5}, {178.62, 0.}}, {"C", "C", "C", "C", "C", "C", "O", "C", 
   "C", "C", "N", "O", "O", "H", "H", "H", "H", "H", "H", "H", "H", 
   "H", "H", "H"}}, {"L-tryptophan", 
  "(2S)-2-azaniumyl-3-(1H-indol-3-yl)propanoate", \!\(\*
StyleBox[
TemplateBox[{
    SubscriptBox["\"C\"", "11"],SubscriptBox["\"H\"", "12"],
     SubscriptBox["\"N\"", "2"],SubscriptBox["\"O\"", "2"]},
"RowDefault"],
StripOnInput->False,
ScriptBaselineShifts->{0.5, 0.75}]\), 
  Quantity[204.23, ("Grams")/("Moles")], 
  "C1=CC=C2C(=C1)C(=CN2)CC(C(=O)[O-])[NH3+]", {"UGG"}, {0.00346737, 
   3.89045*10^-10}, {Quantity[602., ("Kilojoules")/("Moles")], 
   Quantity[346., ("Kilojoules")/("Moles")], 
   Quantity[411., ("Kilojoules")/("Moles")], 
   Quantity[305., ("Kilojoules")/("Moles")], 
   Quantity[799., ("Kilojoules")/("Moles")], 
   Quantity[358., ("Kilojoules")/("Moles")], 
   Quantity[386., ("Kilojoules")/("Moles")], 
   Quantity[459., ("Kilojoules")/(
    "Moles")]}, {{-196., -44.47}, {-196., -126.97}, {-124.55, \
-168.22}, {-53.11, -126.97}, {-53.11, -44.47}, {-124.55, -3.22}, \
{25.36, -152.46}, {73.85, -85.72}, {25.36, -18.97}, {50.85, 
    59.49}, {-4.35, 120.8}, {131.55, 
    76.64}, {50.85, -230.92}, {-124.55, -250.72}, {-267.45, -168.22}, \
{-267.45, -3.22}, {-124.55, 79.28}, {156.35, -85.72}, {76.34, 
    137.95}, {186.75, 15.33}, {157.04, 155.1}, {212.24, 
    93.79}, {161.26, -63.13}, {267.45, 32.48}, {101.84, 
    216.41}, {237.74, 172.26}, {263.23, 250.72}}, {"C", "C", "C", "C",
    "C", "C", "N", "C", "C", "C", "H", "C", "H", "H", "H", "H", "H", 
   "H", "H", "N", "C", "H", "H", "H", "O", "O", "H"}}}
